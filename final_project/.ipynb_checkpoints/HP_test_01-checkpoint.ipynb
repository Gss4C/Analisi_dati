# %%
import ROOT
import particle as pt
import funx as fx
import numpy as np
# Out:
# Welcome to JupyROOT 6.26/04

# %%
H0 = ROOT.TF1("null hypothesys poisson" , "TMath::Poisson(x,2.83)",0, 15)           #Solo GB
H1 = ROOT.TF1("Alternative hypothesys poisson" , "TMath::Poisson(x,5.06)",0, 15)    #BG+Signal

# %%
c=ROOT.TCanvas()
c.Draw()
H0.SetLineColor(ROOT.kBlue)
H0.Draw()
H1.Draw("SAME")

# %%
diff = ROOT.TF1("diff", "TMath::Abs(TMath::Poisson(x,2.83) - TMath::Poisson(x,5.06))",0,10)
x_min = diff.GetMinimumX()
x_min
# Out:
# 3.8376170237485323

# %%
alpha = H0.Integral(x_min,15) 
beta = H1.Integral(0 , x_min)

print("alpha = ", alpha)  #Probabilità di rigettare hp solo fondo anche se vera
print("beta = ", beta)    #Probabilità di rigettare hp segnale+fondo anche se vera

print("1-alpha = ", 1-alpha)  
print("1-beta = ", 1-beta)
# Out:
# alpha =  0.25628310932118953
# beta =  0.31180957362542056
# 1-alpha =  0.7437168906788105
# 1-beta =  0.6881904263745795

# %% [markdown]
# Possiamo escludere quindi l'ipotesi di solo fondo sapendo di sbagliare al $25.6\%$. Ciò significa che possiamo escludere l'ipotesi di fondo con una accuratezza del $74.3\%$
#
# ---
# L'ipotesi di segnale+fondo è compatibile con il segnale che abbiamo osservato, in quanto
# $$ n_{data} = 8\pm 2.83  \qquad n_{signal} = 5.24\pm 2.29 $$

# %%
F1 = ROOT.TF1("Data" , "TMath::Poisson(x,8)",0, 15)          
F2 = ROOT.TF1("Signal " , "TMath::Poisson(x,5.06)",0, 15)    

c=ROOT.TCanvas()
c.Draw()
F1.SetLineColor(ROOT.kBlue)
H0.SetLineColor(ROOT.kGreen)
H0.Draw()
F2.Draw("SAME")
F1.Draw("SAME")
