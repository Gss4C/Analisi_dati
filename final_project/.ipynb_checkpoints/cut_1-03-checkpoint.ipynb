# %% [markdown]
# # Step 1
# Dobbiamo utilizzare un algoritmo meno specializzato e più generalizzato per trovare un'efficienza per la selezione dei muoni prompt.
#
# ---
# | Caratteristica | Criterio stretto | Criterio largo |
# | ------ | ----------- ||
# | $\chi^2$   | $0.2<\chi^2<1.8$ | nada |
# | $dz$ | $<0.005$ | $<0.009$|
# | $dB$  | $<0.003$| $<0,006$ |
# | $iso$  | $<4$ | $<9$ |

# %%
import ROOT
import particle as pt
import numpy as np

fileDY = ROOT.TFile("./datas/DYJets.root","OPEN")
dytr = fileDY.trees.events

file = ROOT.TFile("./datas/Data.root","OPEN")
tr = file.trees.events
# Out:
# Welcome to JupyROOT 6.26/04

# %% [markdown]
# ## Test sul DY

# %%
h_passing_probes = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150) 
h_failing_probes = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150) 
h_all_probes = ROOT.TH1F("DY_allprobes","DY all probes",150,0,150) 
c=ROOT.TCanvas()

n_pass = 0
n_fail = 0

for i in range(dytr.GetEntries()):
    dytr.GetEntry(i)
    if(dytr.muontracks_size>1):
        muons = pt.get_collection(dytr, "muontracks")
        for mi in range(len(muons)):
            if(dytr.muontracks_chi2[mi]<1.8 and dytr.muontracks_chi2[mi]>0.2 and dytr.muontracks_dz[mi]<0.005 and dytr.muontracks_dB[mi]<0.003 and dytr.muontracks_isoDeposits[mi]<4):
                p4t=muons[mi].p4
                for mj in range(len(muons)):
                    if(mj != mi):
                        p4ap=muons[mj].p4
                        s_all = (p4t+p4ap).M()
                        h_all_probes.Fill(s_all)
                        if(dytr.muontracks_dz[mj]<0.009 and dytr.muontracks_dB[mj]<0.006 and dytr.muontracks_isoDeposits[mj]<9):
                            p4pp=muons[mj].p4
                            s_pass = (p4t+p4pp).M()
                            h_passing_probes.Fill(s_pass)
                            #n_pass = n_pass +1
                        else:
                            p4fp=muons[mj].p4
                            s_fail = (p4t+p4fp).M()
                            h_failing_probes.Fill(s_fail)
                            #n_fail = n_fail +1
c.Draw()

h_all_probes.SetLineColor(8)
h_all_probes.SetFillColorAlpha(8,1)
h_all_probes.GetXaxis().SetTitle("E [Gev]")
h_all_probes.GetYaxis().SetTitle("Counts/1GeV")
h_all_probes.Draw()

h_passing_probes.SetLineColor(9)
h_passing_probes.SetFillColorAlpha(9,0.7)
h_passing_probes.Draw("SAME")

leg = ROOT.TLegend(0.1,0.7,0.4,0.9) #0.4,0.7,0.6,0.9
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(h_all_probes, "All probes","f")            
leg.AddEntry(h_passing_probes, "Passing probes","f")
leg.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).

# %%
pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)

pp.SetParameters(50,10,50)
ap.SetParameters(90,10,10,500,100)

h_all_probes.Fit(ap, "SR")
h_passing_probes.Fit(pp, "SR")

c.Draw()
# Out:
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=578.023 FROM MIGRAD    STATUS=CONVERGED     215 CALLS         216 TOTAL
#                      EDM=6.61161e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06916e+01   5.80330e-02   6.68172e-04   4.96838e-04
#    2  p1           3.15183e+00   7.90312e-02   9.09936e-04   2.31841e-04
#    3  p2           2.58293e+03   5.54224e+01   6.51153e-01  -3.44916e-07

# %% [markdown]
# ### Stima efficienza
# A questo punto quel che ci resta da fare è definire le funzioni di segnale e fondo, ottenute dal fit, utilizzare poi gli integrali di quelle per capire quale percentuale di muoni passing in realtà è background.
# Fidandomi del modello potrò dire che l'integrale dell'esponenziale è il numero di probes (totali) di background, l'integrale della gaussiana è invece il numero di eventi di segnale.
# In teoria ciò non dovrebbe avere bias e mi permette di valutare la signal efficiency e la background efficiency

# %%
bkg=ROOT.TF1("Background exp","[1]/[0]*TMath::Exp(-x/[0])",5,140)
sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)

sig.SetParameters(90.68, 3.17, 2759)
bkg.SetParameters(17.7,2309)

# %% [markdown]
# Non capisco, in questo modo sto calcolando la percentuale dei passing che è realmente segnale. Ma in questo modo però non sto facendo una cosa sostanzialmente diversa da quella di prima? Prima io calcolavo l'efficienza della selezione dei muoni col metodo tag&probe come $$\epsilon = \frac{passingprobes}{allprobes}$$Questo mi diceva quanti muoni passing avevo rispetto ai totali. Ora stiamo valutando la qualità dei passing.
# Probabilmente ora mi conviene continuare per questa strada, so dire di tutti i passing che ce ne piace solo circa l'87% (per quanto riguarda i non passing non sono sicuro)
#
# ---
# Mi scrivo alcuni conti qui per averli sotto mano
# $$n_{tot}=n_s+n_b $$
# $$n_p=n_{ps}+n_{pb} $$
# Per stimare i $n_p$ abbiamo usato $$r_s=\frac{n_p}{n_s} \implies n_{ps}=n_pr_s $$
# $$\epsilon_s=\frac{n_{ps}}{n_s} \qquad ; \qquad \epsilon_b = \frac{n_{pb}}{n_b}$$

# %%
n_b = bkg.Integral(0,150)   #questo stima n_b
n_s = sig.Integral(0,150)   #questo stima n_s
n_t = ap.Integral(0,150)    #stima di signal+bg

print("n_s:",int(n_s), "\nn_b:", int(n_b),"\nn_tot:",int(n_t)) #questi valori servno per le efficienze

n_p=pp.Integral(5,140)
print("n_pass:",int(n_p))
# Out:
# n_s: 2320
# n_b: 2308
# n_tot: 4628
# n_pass: 2171

# %%
r_s = n_p/n_s #rapporto fra pass e signal, che % di pass è signal
#r_b = n_p/n_b

n_ps = n_p * r_s
e_s = n_ps/n_s *100

n_pb = n_p - n_ps
e_b = n_pb/n_b *100

print("Signal efficiency:",int(e_s),"\nBackground Efficiency:",int(e_b))#ciò ci dice quanto dei passing è segnale e quanto è fondo
# Out:
# Signal efficiency: 87
# Background Efficiency: 6

# %% [markdown]
# ### Efficiency Scan
# Utilizzo lo stesso metodo per effettuare uno scan dei tagli e trovare le migliori efficienze. Tutto ciò va poi applicato al dataset Data.root

# %%
ea = []
e_max = 0
c1=ROOT.TCanvas()
h_epsilon = ROOT.TH1F("efficiency", "efficiency", 100, 0, 100)
for dzc in np.arange(0.007, 0.015 , 0.001):
    print("sono a dcz = ", dzc)
    for dBc in np.arange(0.006 , 0.010 , 0.001):
        for isoc in np.arange(4, 10, 1):

            h_pass = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150)
            h_all = ROOT.TH1F("DY_allprobes","DY all probes",150,0,150) 

            for i in range(dytr.GetEntries()): #inizio ciclo che crea istogramma con la scelta di parametri
                dytr.GetEntry(i)
                if(dytr.muontracks_size>1):
                    muons = pt.get_collection(dytr, "muontracks")
                    for mi in range(len(muons)):
                        if(dytr.muontracks_chi2[mi]<1.8 and dytr.muontracks_chi2[mi]>0.2 and dytr.muontracks_dz[mi]<0.005 and dytr.muontracks_dB[mi]<0.003 and dytr.muontracks_isoDeposits[mi]<4):
                            p4t=muons[mi].p4
                            for mj in range(len(muons)):
                                if(mj != mi):
                                    p4ap = muons[mj].p4
                                    s_all = (p4t+p4ap).M()
                                    h_all.Fill(s_all)
                                    
                                    if(dytr.muontracks_dz[mj]<dzc and dytr.muontracks_dB[mj]<dBc and dytr.muontracks_isoDeposits[mj]<isoc):
                                        p4pp = muons[mj].p4
                                        s_pass = (p4t+p4pp).M()
                                        h_pass.Fill(s_pass)
            
            pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)
            pp.SetParameters(50,10,50)
            ap.SetParameters(90,10,10,500,100)
            h_all.Fit(ap, "SR")
            h_pass.Fit(pp,"SR")
            n_p=pp.Integral(5,140)

            #bkg=ROOT.TF1("Background gauss","[1]/[0]*TMath::Exp(-x/[0])",5,140)
            #bkg.SetParameters(ap.Getparameter(3),ap.GetParameter(4))
            sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            sig.SetParameters(ap.GetParameter(0),ap.GetParameter(1),ap.GetParameter(2))
            n_s=sig.Integral(5,140)

            ei=pt.eff(n_s,n_p)
            ea.append(ei)
            if(ei>=max(ea)): 
                params=[dzc,dBc,isoc] #lista che contiene i migliori parametri

# %%
cc = ROOT.TCanvas()
cc.Draw()
ee=[]
h_e = ROOT.TH1F("efficiency", "efficiency", 50, 0.75, 1)
for i in range(len(ea)):
    h_e.Fill(ea[i])
h_e.Draw()

# %% [markdown]
# ## Dataset Data.root
# Facciamo un efficiency scan e poi speriamo in gesù

# %%
ea = []
e_max = 0
#params[]
c2=ROOT.TCanvas()
h_epsilon = ROOT.TH1F("efficiency", "efficiency", 100, 0, 100)
for dzc in np.arange(0.007, 0.015 , 0.001):
    print("sono a dcz = ", dzc)
    for dBc in np.arange(0.006 , 0.010 , 0.001):
        for isoc in np.arange(4, 10, 1):

            h_pass = ROOT.TH1F("mu_mass_PP"," Muon mass PP",150,0,150)
            h_all = ROOT.TH1F("allprobes","All probes",150,0,150) 

            for i in range(tr.GetEntries()): #inizio ciclo che crea istogramma con la scelta di parametri
                tr.GetEntry(i)
                if(tr.muontracks_size>1):
                    muons = pt.get_collection(tr, "muontracks")
                    for mi in range(len(muons)):
                        if(tr.muontracks_chi2[mi]<1.8 and tr.muontracks_chi2[mi]>0.2 and tr.muontracks_dz[mi]<0.005 and tr.muontracks_dB[mi]<0.003 and tr.muontracks_isoDeposits[mi]<4):
                            p4t=muons[mi].p4
                            for mj in range(len(muons)):
                                if(mj != mi):
                                    p4ap = muons[mj].p4
                                    s_all = (p4t+p4ap).M()
                                    h_all.Fill(s_all)
                                    
                                    if(tr.muontracks_dz[mj]<dzc and tr.muontracks_dB[mj]<dBc and tr.muontracks_isoDeposits[mj]<isoc):
                                        p4pp = muons[mj].p4
                                        s_pass = (p4t+p4pp).M()
                                        h_pass.Fill(s_pass)
            
            pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)
            pp.SetParameters(50,10,50)
            ap.SetParameters(90,10,10,500,100)
            h_all.Fit(ap, "SR")
            h_pass.Fit(pp,"SR")
            n_p=pp.Integral(5,140)

            #bkg=ROOT.TF1("Background gauss","[1]/[0]*TMath::Exp(-x/[0])",5,140)
            #bkg.SetParameters(ap.Getparameter(3),ap.GetParameter(4))
            sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            sig.SetParameters(ap.GetParameter(0),ap.GetParameter(1),ap.GetParameter(2))
            n_s=sig.Integral(5,140)

            ei=pt.eff(n_s,n_p)
            ea.append(ei)
            if(ei>=max(ea)): 
                params=[dzc,dBc,isoc]
print("Max efficiency:",max(ea),"\ndz at cut:",params[0],"\ndB at cut:",params[1],"\nisoDeposits at cut:",params[2])
# Out:
# sono a dcz =  0.007
# sono a dcz =  0.008
# sono a dcz =  0.009000000000000001
# sono a dcz =  0.01
# sono a dcz =  0.011
# sono a dcz =  0.012
# sono a dcz =  0.013000000000000001
# sono a dcz =  0.014
# Max efficiency: 0.908965638057565
# dz at cut: 0.014
# dB at cut: 0.007
# isoDeposits at cut: 9
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=808.19 FROM MIGRAD    STATUS=CONVERGED     104 CALLS         105 TOTAL
#                      EDM=2.92361e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06555e+01   5.90900e-02   8.05449e-04  -3.73632e-03
#    2  p1           3.14838e+00   7.99418e-02   1.08968e-03   8.00705e-04
#    3  p2           2.47808e+03   5.42858e+01   7.53985e-01  -2.73154e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=2461.25 FROM MIGRAD    STATUS=CALL LIMIT   1351 CALLS        1352 TOTAL
#                      EDM=0.00103592    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  44.6 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.55945e+03   6.05840e+02  -6.63153e+00  -5.30521e-03
#    2  p1           6.45863e+02   1.80294e+02   1.32647e+00  -1.17934e-02
#    3  p2           6.23019e+05   9.05687e+05   1.22580e+04  -1.59562e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=2470.73 FROM MIGRAD    STATUS=CALL LIMIT   1345 CALLS        1346 TOTAL
#                      EDM=0.00182799    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  42.6 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.45886e+03   3.25770e+02  -4.17743e+00  -7.63409e-03
#    2  p1           5.34837e+02   8.96123e+01   4.65047e-01  -1.99710e-02
#    3  p2           1.94163e+06   2.23404e+06   4.14038e+04  -5.51966e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=946.585 FROM MIGRAD    STATUS=CONVERGED     218 CALLS         219 TOTAL
#                      EDM=5.43291e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06795e+01   5.85793e-02   8.63623e-04   1.70037e-02
#    2  p1           3.15524e+00   8.01628e-02   1.18184e-03  -1.80534e-03
#    3  p2           2.53588e+03   5.49153e+01   8.25378e-01  -2.39195e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=982.016 FROM MIGRAD    STATUS=CONVERGED     116 CALLS         117 TOTAL
#                      EDM=4.71393e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06788e+01   5.85692e-02   8.79669e-04  -1.40458e-02
#    2  p1           3.15920e+00   7.98411e-02   1.19931e-03  -8.35661e-03
#    3  p2           2.54251e+03   5.49870e+01   8.41764e-01   3.35029e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1024.35 FROM MIGRAD    STATUS=CONVERGED     136 CALLS         137 TOTAL
#                      EDM=3.21601e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06788e+01   5.85845e-02   8.98142e-04  -1.03419e-04
#    2  p1           3.15914e+00   8.00265e-02   1.22685e-03  -3.22957e-04
#    3  p2           2.54330e+03   5.49955e+01   8.59833e-01  -3.16402e-09
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=819.264 FROM MIGRAD    STATUS=CONVERGED     108 CALLS         109 TOTAL
#                      EDM=4.39366e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06522e+01   5.91845e-02   8.12435e-04   1.11474e-02
#    2  p1           3.15862e+00   8.01833e-02   1.10068e-03  -5.61409e-03
#    3  p2           2.48512e+03   5.43630e+01   7.60205e-01  -6.57403e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=870.548 FROM MIGRAD    STATUS=CONVERGED     274 CALLS         275 TOTAL
#                      EDM=5.64861e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.7 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06686e+01   6.06550e-02  -2.55621e-04  -1.95934e-02
#    2  p1           3.17465e+00   8.12916e-02   5.23537e-04   5.93925e-03
#    3  p2           2.51928e+03   5.54725e+01   4.42737e-01   9.57564e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=2486.83 FROM MIGRAD    STATUS=CALL LIMIT   1350 CALLS        1351 TOTAL
#                      EDM=0.00299611    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  35.2 per cent
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.47319e+03   1.89628e+02   3.37496e+00  -2.51351e-03
#    2  p1           5.26089e+02   6.79050e+01  -1.60385e+00  -7.12328e-03
#    3  p2           2.60247e+06   2.07966e+06   2.20376e+04  -1.44100e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=961.631 FROM MIGRAD    STATUS=CONVERGED     220 CALLS         221 TOTAL
#                      EDM=2.05887e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06761e+01   5.86827e-02   8.72076e-04   3.70564e-04
#    2  p1           3.16558e+00   8.04140e-02   1.19502e-03   1.00146e-03
#    3  p2           2.54297e+03   5.49919e+01   8.33066e-01   3.39764e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=997.061 FROM MIGRAD    STATUS=CONVERGED     117 CALLS         118 TOTAL
#                      EDM=6.39951e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86708e-02   8.88041e-04   2.95952e-03
#    2  p1           3.16950e+00   8.00925e-02   1.21233e-03   9.75065e-05
#    3  p2           2.54962e+03   5.50635e+01   8.49361e-01   2.03071e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1040.39 FROM MIGRAD    STATUS=CONVERGED     133 CALLS         134 TOTAL
#                      EDM=7.59563e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86889e-02   9.06845e-04   5.75330e-04
#    2  p1           3.16948e+00   8.02874e-02   1.24058e-03  -1.07043e-04
#    3  p2           2.55038e+03   5.50721e+01   8.67739e-01  -2.51119e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=837.264 FROM MIGRAD    STATUS=CONVERGED     204 CALLS         205 TOTAL
#                      EDM=2.43815e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.9 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06522e+01   5.93003e-02  -1.78761e-06   4.10212e-04
#    2  p1           3.15864e+00   8.02902e-02  -2.29949e-05   2.70815e-04
#    3  p2           2.48513e+03   5.43683e+01  -8.04005e-02  -9.32386e-08
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=888.548 FROM MIGRAD    STATUS=CONVERGED     121 CALLS         122 TOTAL
#                      EDM=6.60366e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.9 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06687e+01   5.88955e-02   6.69490e-04   1.33734e-02
#    2  p1           3.17466e+00   8.06191e-02  -9.69605e-04   1.27925e-02
#    3  p2           2.51931e+03   5.48167e+01   1.88440e-01   1.87701e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=923.931 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
#                      EDM=6.04918e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.1 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06745e+01   6.20472e-02   3.44097e-05   5.68923e-03
#    2  p1           3.17131e+00   8.04665e-02  -2.39643e-04  -1.03905e-03
#    3  p2           2.53548e+03   5.61499e+01   2.20244e-02   4.12377e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=983.631 FROM MIGRAD    STATUS=CONVERGED     124 CALLS         125 TOTAL
#                      EDM=2.60897e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06761e+01   5.86828e-02   8.82161e-04  -3.80213e-03
#    2  p1           3.16558e+00   8.04142e-02   1.20886e-03   2.74106e-04
#    3  p2           2.54296e+03   5.49919e+01   8.42531e-01  -7.02909e-09
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1019.06 FROM MIGRAD    STATUS=CONVERGED     133 CALLS         134 TOTAL
#                      EDM=5.09746e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86715e-02   8.97665e-04   1.67267e-03
#    2  p1           3.16950e+00   8.00935e-02   1.22542e-03   3.15797e-04
#    3  p2           2.54959e+03   5.50635e+01   8.58672e-01  -5.39814e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1062.39 FROM MIGRAD    STATUS=CONVERGED     177 CALLS         178 TOTAL
#                      EDM=1.08209e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86891e-02   9.17036e-04   7.27667e-03
#    2  p1           3.16954e+00   8.02878e-02   1.25451e-03   1.84513e-02
#    3  p2           2.55039e+03   5.50721e+01   8.76856e-01   3.41321e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=847.264 FROM MIGRAD    STATUS=CONVERGED     119 CALLS         120 TOTAL
#                      EDM=5.26676e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06522e+01   5.91845e-02   8.26273e-04  -2.11234e-04
#    2  p1           3.15864e+00   8.01833e-02   1.11944e-03  -3.26313e-04
#    3  p2           2.48513e+03   5.43630e+01   7.73072e-01  -3.37850e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=898.548 FROM MIGRAD    STATUS=CONVERGED      98 CALLS          99 TOTAL
#                      EDM=8.47224e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.4 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06686e+01   5.93352e-02  -3.86836e-04  -1.17462e-02
#    2  p1           3.17461e+00   8.07826e-02  -9.51497e-04  -6.00895e-03
#    3  p2           2.51932e+03   5.61329e+01  -4.68666e-01   2.80196e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=935.931 FROM MIGRAD    STATUS=CONVERGED     161 CALLS         162 TOTAL
#                      EDM=4.02187e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06745e+01   5.88567e-02   8.63183e-04   7.48422e-05
#    2  p1           3.17132e+00   8.04284e-02   1.17955e-03   9.07614e-05
#    3  p2           2.53547e+03   5.49109e+01   8.20658e-01   8.17805e-08
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=997.631 FROM MIGRAD    STATUS=CONVERGED     129 CALLS         130 TOTAL
#                      EDM=5.62559e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06761e+01   5.86823e-02   8.87825e-04  -7.30132e-04
#    2  p1           3.16560e+00   8.04135e-02   1.21668e-03   6.09038e-03
#    3  p2           2.54299e+03   5.49919e+01   8.48498e-01   1.70150e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1034.06 FROM MIGRAD    STATUS=CONVERGED     113 CALLS         114 TOTAL
#                      EDM=7.38173e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86715e-02   9.04253e-04   7.26908e-05
#    2  p1           3.16950e+00   8.00934e-02   1.23441e-03  -1.55349e-04
#    3  p2           2.54959e+03   5.50635e+01   8.64962e-01   6.50409e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1078.39 FROM MIGRAD    STATUS=CONVERGED     212 CALLS         213 TOTAL
#                      EDM=1.02669e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86890e-02   9.23268e-04   5.91101e-03
#    2  p1           3.16949e+00   8.02876e-02   1.26307e-03   2.06303e-03
#    3  p2           2.55038e+03   5.50721e+01   8.83429e-01  -5.13540e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=842.42 FROM MIGRAD    STATUS=CONVERGED      96 CALLS          97 TOTAL
#                      EDM=2.82528e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.1 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06637e+01   5.89241e-02  -3.51353e-05  -4.23730e-04
#    2  p1           3.14326e+00   7.91910e-02   5.70075e-05  -3.16176e-04
#    3  p2           2.49802e+03   5.45092e+01   2.65142e-02   5.01522e-08
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=892.667 FROM MIGRAD    STATUS=CONVERGED     165 CALLS         166 TOTAL
#                      EDM=5.44682e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06800e+01   5.87571e-02   2.48234e-04   5.77290e-04
#    2  p1           3.15897e+00   8.00366e-02  -1.59728e-04   5.38018e-04
#    3  p2           2.53223e+03   6.22305e+01   2.53488e-02   6.91895e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=928.039 FROM MIGRAD    STATUS=CONVERGED     148 CALLS         149 TOTAL
#                      EDM=1.26138e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06858e+01   5.85244e-02   8.53153e-04   3.19377e-03
#    2  p1           3.15566e+00   7.93773e-02   1.15714e-03   4.13083e-03
#    3  p2           2.54843e+03   5.50509e+01   8.19279e-01   6.66539e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=983.758 FROM MIGRAD    STATUS=CONVERGED     103 CALLS         104 TOTAL
#                      EDM=6.3269e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06869e+01   5.82996e-02   8.75435e-04  -1.15825e-02
#    2  p1           3.14848e+00   7.93306e-02   1.19124e-03  -3.62813e-03
#    3  p2           2.55706e+03   5.51444e+01   8.44921e-01  -1.62764e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1020.13 FROM MIGRAD    STATUS=CONVERGED     158 CALLS         159 TOTAL
#                      EDM=1.76865e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06863e+01   5.82894e-02   8.90743e-04  -1.88776e-03
#    2  p1           3.15251e+00   7.90091e-02   1.20737e-03  -1.47813e-03
#    3  p2           2.56378e+03   5.52165e+01   8.61508e-01   2.20254e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1065.46 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
#                      EDM=7.4031e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06863e+01   5.83049e-02   9.10309e-04  -5.73797e-03
#    2  p1           3.15242e+00   7.91878e-02   1.23638e-03  -4.49479e-04
#    3  p2           2.56456e+03   5.52250e+01   8.80561e-01  -3.61067e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=855.535 FROM MIGRAD    STATUS=CONVERGED     108 CALLS         109 TOTAL
#                      EDM=1.40625e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06602e+01   5.89532e-02   8.25991e-04   2.83653e-03
#    2  p1           3.15350e+00   7.93712e-02   1.11215e-03   4.97276e-04
#    3  p2           2.50502e+03   5.45801e+01   7.79934e-01  -6.40825e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=907.703 FROM MIGRAD    STATUS=CONVERGED     144 CALLS         145 TOTAL
#                      EDM=4.81287e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06765e+01   5.88084e-02   8.48888e-04   2.99107e-03
#    2  p1           3.16929e+00   7.98857e-02   1.15312e-03   1.88391e-03
#    3  p2           2.53932e+03   5.49524e+01   8.08813e-01   4.19176e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=944.112 FROM MIGRAD    STATUS=CONVERGED     104 CALLS         105 TOTAL
#                      EDM=4.85832e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   4.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06822e+01   6.04611e-02  -6.72941e-04   2.89150e-03
#    2  p1           3.16597e+00   8.47030e-02  -4.55310e-04   1.34983e-02
#    3  p2           2.55549e+03   5.54882e+01   6.41142e-01   1.27375e-05
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1000.85 FROM MIGRAD    STATUS=CONVERGED     109 CALLS         110 TOTAL
#                      EDM=3.78499e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06833e+01   5.84025e-02   8.84091e-04   2.50931e-05
#    2  p1           3.15879e+00   7.95881e-02   1.20480e-03  -3.05819e-04
#    3  p2           2.56411e+03   5.52201e+01   8.53392e-01   2.20240e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1037.21 FROM MIGRAD    STATUS=CONVERGED     136 CALLS         137 TOTAL
#                      EDM=2.28911e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06828e+01   5.83918e-02   8.99680e-04  -6.73111e-03
#    2  p1           3.16274e+00   7.92684e-02   1.22129e-03  -7.72185e-03
#    3  p2           2.57081e+03   5.52922e+01   8.69876e-01   2.87550e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1083.55 FROM MIGRAD    STATUS=CONVERGED     123 CALLS         124 TOTAL
#                      EDM=2.76095e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06828e+01   5.84093e-02   9.19827e-04   5.57981e-04
#    2  p1           3.16272e+00   7.94556e-02   1.25129e-03  -1.81292e-03
#    3  p2           2.57160e+03   5.53007e+01   8.89212e-01  -3.20997e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=873.535 FROM MIGRAD    STATUS=CONVERGED     173 CALLS         174 TOTAL
#                      EDM=4.3771e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06602e+01   5.89532e-02   8.34290e-04   1.52555e-03
#    2  p1           3.15350e+00   7.93711e-02   1.12324e-03  -1.66566e-04
#    3  p2           2.50502e+03   5.45801e+01   7.88087e-01  -7.80591e-08
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=925.703 FROM MIGRAD    STATUS=CONVERGED     137 CALLS         138 TOTAL
#                      EDM=6.72419e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06765e+01   5.88085e-02   8.57190e-04  -9.56352e-04
#    2  p1           3.16928e+00   7.98858e-02   1.16442e-03  -1.32746e-03
#    3  p2           2.53931e+03   5.49524e+01   8.16785e-01   6.73311e-07
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=962.112 FROM MIGRAD    STATUS=CONVERGED     179 CALLS         180 TOTAL
#                      EDM=3.0067e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06822e+01   5.86251e-02   8.70252e-04   3.59776e-03
#    2  p1           3.16593e+00   7.96230e-02   1.18196e-03   1.05826e-04
#    3  p2           2.55548e+03   5.51270e+01   8.35320e-01   2.31635e-06
#  FCN=498.471 FROM MIGRAD    STATUS=CONVERGED     321 CALLS         322 TOTAL
#                      EDM=5.57724e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06953e+01   5.72493e-02   2.01078e-04  -3.52770e-03
#    2  p1           3.16735e+00   7.74652e-02   6.02227e-05  -2.24846e-03
#    3  p2           2.76886e+03   5.88663e+01   8.47245e-02   3.34437e-06
#    4  p3           1.38997e+01   1.78260e-01   8.08982e-04   1.22154e-03
#    5  p4           1.31380e+04   1.47350e+02  -1.83478e-01   2.35061e-06
#  FCN=1022.85 FROM MIGRAD    STATUS=CONVERGED     113 CALLS         114 TOTAL
# ...
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: allprobes (Potential memory leak).

# %%
print("Max efficiency:",max(ea),"\ndz at cut:",params[0],"\ndB at cut:",params[1],"\nisoDeposits at cut:",params[2])
# Out:
# Max efficiency: 0.908965638057565
# dz at cut: 0.014
# dB at cut: 0.007
# isoDeposits at cut: 9

# %%
cc = ROOT.TCanvas()
cc.Draw()
ee=[]
h_e = ROOT.TH1F("efficiency", "efficiency", 50, 0.75, 1)
for i in range(len(ea)):
    h_e.Fill(ea[i])
h_e.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: efficiency (Potential memory leak).
