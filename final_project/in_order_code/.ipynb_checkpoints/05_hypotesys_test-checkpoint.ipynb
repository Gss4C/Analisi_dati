# %% [markdown]
# # Step 2 - Test d'ipotesi
# Vogliamo testare l'ipotesi di solo fondo con quella di Segnale + Fondo ed entrambe saranno testate effettuando la correzione dell'aggiunta di 7.905 eventi, come osservato debba accadere nel notebook *04_cut_revert.ipynb*

# %%
import ROOT
import particle as pt
import funx as fx
import numpy as np
# Out:
# Welcome to JupyROOT 6.26/04

# %%
H0 = ROOT.TF1("null hypothesys poisson" , "TMath::Poisson(x,10.74)",0, 30)  #Solo GB
H1 = ROOT.TF1("Correction Poisson" , "TMath::Poisson(x,13.1)",0, 30)        #BG+Signal

c=ROOT.TCanvas()
c.Draw()
H0.SetLineColor(ROOT.kBlue)
H0.Draw()
H1.Draw("SAME")

leg = ROOT.TLegend(0.98,0.9,0.78,0.75) #x1,y1 (coordinate punto alto dx), x2,y2 (coordinate punto basso sx)
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(H0, "BKG","f")            
leg.AddEntry(H1, "BKG+SIG","f")
leg.Draw()

# %% [markdown]
# Vediamo come entrambe le ipotesi non sono compatibili coi nostri dati. Per farlo effettuo l'integrale da 13 in poi, ossia dove abbiamo il nostro risultato ottenuto dai dati

# %%
bg_data_c = H0.Integral(13,30)   #Compatibilità hp solo fondo coi dati
sig_c = H1.Integral(13,30)            #Compatibilità hp segnale+fondo (non corretto) coi dati 

print("alpha = ", bg_data_c)  #Probabilità di rigettare hp solo fondo anche se vera
print("beta = ", sig_c)    #Probabilità di rigettare hp segnale+fondo anche se vera
# Out:
# alpha =  0.2375349160928502
# beta =  0.49258857381262344
