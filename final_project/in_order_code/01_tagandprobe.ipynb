# %% [markdown]
# # Step 1 - Algoritmo di Tag And Probe
# Dobbiamo utilizzare un algoritmo meno specializzato e più generalizzato per trovare un'efficienza per la selezione dei muoni prompt.
#
# ---
# | Caratteristica | Criterio stretto | Criterio largo |
# | ------ | ----------- ||
# | $\chi^2$   | $0.2<\chi^2<1.8$ | nada |
# | $dz$ | $<0.005$ | $<0.009$|
# | $dB$  | $<0.003$| $<0,006$ |
# | $iso$  | $<4$ | $<9$ |

# %%
import ROOT
import particle as pt
import numpy as np

fileDY = ROOT.TFile("../datas/DYJets.root","OPEN")
dytr = fileDY.trees.events

file = ROOT.TFile("../datas/Data.root","OPEN")
tr = file.trees.events

# %% [markdown]
# ## Test sul DY
# Questo è un primo test utilizzato per sviluppare l'algoritmo e vedere se girava. Dopo di questo saremo dovuti passare al tag and probe fatto con uno scan per trovare la migliore efficienza

# %%
h_passing_probes = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150) 
h_failing_probes = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150) 
h_all_probes = ROOT.TH1F("DY_allprobes","DY all probes",150,0,150) 
c=ROOT.TCanvas()

for i in range(dytr.GetEntries()):
    dytr.GetEntry(i)
    if(dytr.muontracks_size>1):
        muons = pt.get_collection(dytr, "muontracks")
        for mi in range(len(muons)):
            if(dytr.muontracks_chi2[mi]<1.8 and dytr.muontracks_chi2[mi]>0.2 and dytr.muontracks_dz[mi]<0.005 and dytr.muontracks_dB[mi]<0.003 and dytr.muontracks_isoDeposits[mi]<4):
                p4t=muons[mi].p4
                for mj in range(len(muons)):
                    if(mj != mi):
                        p4ap=muons[mj].p4
                        s_all = (p4t+p4ap).M()
                        h_all_probes.Fill(s_all)
                        if(dytr.muontracks_dz[mj]<0.009 and dytr.muontracks_dB[mj]<0.006 and dytr.muontracks_isoDeposits[mj]<9):
                            p4pp=muons[mj].p4
                            s_pass = (p4t+p4pp).M()
                            h_passing_probes.Fill(s_pass)
                        else:
                            p4fp=muons[mj].p4
                            s_fail = (p4t+p4fp).M()
                            h_failing_probes.Fill(s_fail)
c.Draw()

h_all_probes.SetLineColor(8)
h_all_probes.SetFillColorAlpha(8,1)
h_all_probes.GetXaxis().SetTitle("E [Gev]")
h_all_probes.GetYaxis().SetTitle("Counts/1GeV")
h_all_probes.Draw()

h_passing_probes.SetLineColor(9)
h_passing_probes.SetFillColorAlpha(9,0.7)
h_passing_probes.Draw("SAME")

leg = ROOT.TLegend(0.1,0.7,0.4,0.9) #0.4,0.7,0.6,0.9
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(h_all_probes, "All probes","f")            
leg.AddEntry(h_passing_probes, "Passing probes","f")
leg.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).

# %%
pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)

pp.SetParameters(50,10,50)
ap.SetParameters(90,10,10,500,100)

h_all_probes.Fit(ap, "SR")
h_passing_probes.Fit(pp, "SR")

c.Draw()
# Out:
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=578.023 FROM MIGRAD    STATUS=CONVERGED     215 CALLS         216 TOTAL
#                      EDM=6.61161e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06916e+01   5.80330e-02   6.68172e-04   4.96838e-04
#    2  p1           3.15183e+00   7.90312e-02   9.09936e-04   2.31841e-04
#    3  p2           2.58293e+03   5.54224e+01   6.51153e-01  -3.44916e-07

# %% [markdown]
# ### Stima efficienza
# A questo punto quel che ci resta da fare è definire le funzioni di segnale e fondo, ottenute dal fit, utilizzare poi gli integrali di quelle per capire quale percentuale di muoni passing in realtà è background.
# Fidandomi del modello potrò dire che l'integrale dell'esponenziale è il numero di probes (totali) di background, l'integrale della gaussiana è invece il numero di eventi di segnale.
# In teoria ciò non dovrebbe avere bias e mi permette di valutare la signal efficiency e la background efficiency

# %%
bkg=ROOT.TF1("Background exp","[1]/[0]*TMath::Exp(-x/[0])",5,140)
sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)

sig.SetParameters(90.68, 3.17, 2759)
bkg.SetParameters(17.7,2309)

# %% [markdown]
# Non capisco, in questo modo sto calcolando la percentuale dei passing che è realmente segnale. Ma in questo modo però non sto facendo una cosa sostanzialmente diversa da quella di prima? Prima io calcolavo l'efficienza della selezione dei muoni col metodo tag&probe come $$\epsilon = \frac{passingprobes}{allprobes}$$Questo mi diceva quanti muoni passing avevo rispetto ai totali. Ora stiamo valutando la qualità dei passing.
# Probabilmente ora mi conviene continuare per questa strada, so dire di tutti i passing che ce ne piace solo circa l'87% (per quanto riguarda i non passing non sono sicuro)
#
# ---
# Mi scrivo alcuni conti qui per averli sotto mano
# $$n_{tot}=n_s+n_b $$
# $$n_p=n_{ps}+n_{pb} $$
# Per stimare i $n_p$ abbiamo usato $$r_s=\frac{n_p}{n_s} \implies n_{ps}=n_pr_s $$
# $$\epsilon_s=\frac{n_{ps}}{n_s} \qquad ; \qquad \epsilon_b = \frac{n_{pb}}{n_b}$$

# %%
n_b = bkg.Integral(0,150)   #questo stima n_b
n_s = sig.Integral(0,150)   #questo stima n_s
n_t = ap.Integral(0,150)    #stima di signal+bg

print("n_s:",int(n_s), "\nn_b:", int(n_b),"\nn_tot:",int(n_t)) #questi valori servno per le efficienze

n_p=pp.Integral(5,140)
print("n_pass:",int(n_p))
# Out:
# n_s: 2320
# n_b: 2308
# n_tot: 4628
# n_pass: 2171

# %%
r_s = n_p/n_s #rapporto fra pass e signal, che % di pass è signal
#r_b = n_p/n_b

n_ps = n_p * r_s
e_s = n_ps/n_s *100

n_pb = n_p - n_ps
e_b = n_pb/n_b *100

print("Signal efficiency:",int(e_s),"\nBackground Efficiency:",int(e_b))#ciò ci dice quanto dei passing è segnale e quanto è fondo
# Out:
# Signal efficiency: 87
# Background Efficiency: 6

# %% [markdown]
# ## Efficiency Scan
# Utilizzo lo stesso metodo per effettuare uno scan dei tagli e trovare le migliori efficienze. Tutto ciò va poi applicato al dataset Data.root

# %%
ea = []
e_max = 0
c1=ROOT.TCanvas()
h_epsilon = ROOT.TH1F("efficiency", "efficiency", 100, 0, 100)
for dzc in np.arange(0.007, 0.015 , 0.001):
    print("Sono al dcz = ", dzc)
    for dBc in np.arange(0.006 , 0.010 , 0.001):
        for isoc in np.arange(4, 10, 1):
            h_pass = ROOT.TH1F("DY_mu_mass_PP","DY Muon mass PP",150,0,150)
            h_all = ROOT.TH1F("DY_allprobes","DY all probes",150,0,150) 
            for i in range(dytr.GetEntries()): #inizio ciclo che crea istogramma con la scelta di parametri
                dytr.GetEntry(i)
                if(dytr.muontracks_size>1):
                    muons = pt.get_collection(dytr, "muontracks")
                    for mi in range(len(muons)):
                        if(dytr.muontracks_chi2[mi]<1.8 and dytr.muontracks_chi2[mi]>0.2 and dytr.muontracks_dz[mi]<0.005 and dytr.muontracks_dB[mi]<0.003 and dytr.muontracks_isoDeposits[mi]<4):
                            p4t=muons[mi].p4               #Quadrimpulso muone tag
                            for mj in range(len(muons)):
                                if(mj != mi):              #Qui prendo tutti i probes
                                    p4ap = muons[mj].p4
                                    s_all = (p4t+p4ap).M()
                                    h_all.Fill(s_all)
                                    
                                    if(dytr.muontracks_dz[mj]<dzc and dytr.muontracks_dB[mj]<dBc and dytr.muontracks_isoDeposits[mj]<isoc):
                                        p4pp = muons[mj].p4
                                        s_pass = (p4t+p4pp).M()
                                        h_pass.Fill(s_pass)
            
            pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)
            pp.SetParameters(50,10,50)
            ap.SetParameters(90,10,10,500,100)
            h_all.Fit(ap, "SR")
            h_pass.Fit(pp,"SR")
            n_p=pp.Integral(5,140)

            bkg=ROOT.TF1("Background gauss","[1]/[0]*TMath::Exp(-x/[0])",5,140)
            bkg.SetParameters(ap.GetParameter(3),ap.GetParameter(4))
            n_b = bkg.Integral(5,140)
            
            sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            sig.SetParameters(ap.GetParameter(0),ap.GetParameter(1),ap.GetParameter(2))
            n_s=sig.Integral(5,140)

            ei, ebi =pt.eff(n_s,n_b,n_p)
            ea.append(ei)
            if(ei>=max(ea)): 
                params=[dzc,dBc,isoc, ebi] #lista che contiene i migliori parametri
# Out:
# Sono al dcz =  0.007
# Sono al dcz =  0.008
# Sono al dcz =  0.009000000000000001
# Sono al dcz =  0.01
# Sono al dcz =  0.011
# Sono al dcz =  0.012
# Sono al dcz =  0.013000000000000001
# Sono al dcz =  0.014
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=515.19 FROM MIGRAD    STATUS=CONVERGED     136 CALLS         137 TOTAL
#                      EDM=2.14445e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06555e+01   5.90900e-02   6.43443e-04   6.40815e-05
#    2  p1           3.14837e+00   7.99419e-02   8.70507e-04   6.94522e-05
#    3  p2           2.47808e+03   5.42858e+01   6.02202e-01   3.64649e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=527.553 FROM MIGRAD    STATUS=CONVERGED     157 CALLS         158 TOTAL
#                      EDM=5.62227e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06720e+01   5.78578e-02  -6.93259e-04   2.07033e-02
#    2  p1           3.16428e+00   8.05182e-02  -6.56388e-05   2.29711e-03
#    3  p2           2.51212e+03   5.42926e+01  -9.71434e-01  -1.47885e-05
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=533.897 FROM MIGRAD    STATUS=CONVERGED     152 CALLS         153 TOTAL
#                      EDM=2.21819e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06779e+01   5.87562e-02   6.50988e-04   3.02917e-04
#    2  p1           3.16102e+00   8.01902e-02   8.88466e-04   1.32504e-04
#    3  p2           2.52838e+03   5.48340e+01   6.19206e-01   1.70305e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=544.585 FROM MIGRAD    STATUS=CONVERGED     118 CALLS         119 TOTAL
#                      EDM=5.10635e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.
-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=534.548 FROM MIGRAD    STATUS=CONVERGED     848 CALLS         849 TOTAL
#                      EDM=1.32404e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06686e+01   5.89211e-02  -1.05215e-05   1.39098e-03
#    2  p1           3.17462e+00   8.04856e-02   1.31382e-04  -1.00612e-03
#    3  p2           2.51927e+03   5.42074e+01  -4.41586e-02  -3.26253e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=540.931 FROM MIGRAD    STATUS=CONVERGED     132 CALLS         133 TOTAL
#                      EDM=8.67929e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06745e+01   5.88570e-02   6.56322e-04  -2.48876e-03
#    2  p1           3.17133e+00   8.04287e-02   8.96877e-04   4.44352e-03
#    3  p2           2.53547e+03   5.49109e+01   6.24138e-01   1.18519e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=552.631 FROM MIGRAD    STATUS=CONVERGED     102 CALLS         103 TOTAL
#                      EDM=2.20929e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.5 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06761e+01   5.86271e-02   6.95170e-05   9.70674e-05
#    2  p1           3.16558e+00   8.03508e-02   6.35225e-06  -3.17451e-04
#    3  p2           2.54296e+03   5.48475e+01   4.06439e-02  -1.01793e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=557.061 FROM MIGRAD    STATUS=CONVERGED     181 CALLS         182 TOTAL
#                      EDM=7.1939e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86719e-02   6.64014e-04  -5.49878e-03
#    2  p1           3.16950e+00   8.00939e-02   9.06451e-04  -8.64813e-04
#    3  p2           2.54958e+03   5.50635e+01   6.35119e-01  -3.79570e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=562.392 FROM MIGRAD    STATUS=CONVERGED     144 CALLS         145 TOTAL
#                      EDM=4.94911e-11    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.2 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.87297e-02   8.99884e-05  -1.64119e-04
#    2  p1           3.16948e+00   8.02945e-02  -3.51463e-04  -5.17040e-05
#    3  p2           2.55038e+03   5.51221e+01   4.03983e-02   1.63544e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=524.264 FROM MIGRAD    STATUS=CONVERGED     114 CALLS         115 TOTAL
#                      EDM=2.03235e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.5 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06522e+01   6.41108e-02   1.26924e-05   6.57029e-03
#    2  p1           3.15861e+00   8.55389e-02  -1.63459e-04  -6.89105e-03
#    3  p2           2.48513e+03   5.55125e+01  -1.82585e-01  -1.35222e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=536.548 FROM MIGRAD    STATUS=CONVERGED     171 CALLS         172 TOTAL
#                      EDM=1.1522e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06686e+01   5.90431e-02   6.57247e-04  -7.27517e-03
#    2  p1           3.17462e+00   8.07079e-02   8.98439e-04  -1.04972e-03
#    3  p2           2.51928e+03   5.47352e+01   6.19621e-01   4.17927e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=542.931 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
#                      EDM=1.59029e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.8 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06745e+01   5.88132e-02  -2.18857e-04  -6.13950e-03
#    2  p1           3.17130e+00   8.32149e-02  -5.17588e-05  -5.02984e-03
#    3  p2           2.53546e+03   5.49290e+01  -4.15562e-01  -9.87576e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=556.631 FROM MIGRAD    STATUS=CONVERGED     113 CALLS         114 TOTAL
#                      EDM=6.69594e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06761e+01   5.86824e-02   6.63946e-04  -4.98154e-03
#    2  p1           3.16559e+00   8.04136e-02   9.09856e-04   4.67963e-03
#    3  p2           2.54299e+03   5.49919e+01   6.34049e-01   1.88051e-05
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=561.061 FROM MIGRAD    STATUS=CONVERGED     194 CALLS         195 TOTAL
#                      EDM=3.83699e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06755e+01   5.86717e-02   6.66330e-04   1.24439e-03
#    2  p1           3.16950e+00   8.00936e-02   9.09617e-04  -1.22882e-04
#    3  p2           2.54959e+03   5.50635e+01   6.37391e-01  -8.05468e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN
-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06822e+01   5.86253e-02   6.57692e-04   4.77799e-03
#    2  p1           3.16593e+00   7.96234e-02   8.93255e-04   1.62239e-03
#    3  p2           2.55547e+03   5.51270e+01   6.31306e-01   3.45555e-08
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=560.849 FROM MIGRAD    STATUS=CONVERGED     135 CALLS         136 TOTAL
#                      EDM=1.23033e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06833e+01   5.84023e-02   6.61886e-04   2.47492e-03
#    2  p1           3.15879e+00   7.95879e-02   9.01919e-04   9.87059e-04
#    3  p2           2.56412e+03   5.52201e+01   6.39083e-01   8.56373e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=565.215 FROM MIGRAD    STATUS=CONVERGED     128 CALLS         129 TOTAL
#                      EDM=2.01171e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06828e+01   5.83921e-02   6.64593e-04   1.09082e-03
#    2  p1           3.16276e+00   7.92688e-02   9.02204e-04   9.44793e-05
#    3  p2           2.57081e+03   5.52922e+01   6.42399e-01   1.82904e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=570.55 FROM MIGRAD    STATUS=CONVERGED     131 CALLS         132 TOTAL
#                      EDM=2.5285e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06828e+01   5.84095e-02   6.67580e-04  -3.52937e-03
#    2  p1           3.16273e+00   7.94558e-02   9.08116e-04  -1.50486e-04
#    3  p2           2.57160e+03   5.53007e+01   6.45517e-01  -1.70973e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=536.535 FROM MIGRAD    STATUS=CONVERGED     196 CALLS         197 TOTAL
#                      EDM=3.11166e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06602e+01   5.89533e-02   6.53977e-04  -1.64142e-03
#    2  p1           3.15351e+00   7.93712e-02   8.80449e-04   1.18599e-03
#    3  p2           2.50503e+03   5.45801e+01   6.17858e-01   3.68205e-06
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=548.703 FROM MIGRAD    STATUS=CONVERGED     133 CALLS         134 TOTAL
#                      EDM=3.43726e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06765e+01   5.88087e-02   6.60191e-04  -1.10279e-03
#    2  p1           3.16928e+00   7.98860e-02   8.96802e-04  -4.11300e-04
#    3  p2           2.53931e+03   5.49524e+01   6.29073e-01   8.95277e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=555.112 FROM MIGRAD    STATUS=CONVERGED     125 CALLS         126 TOTAL
#                      EDM=3.75374e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06822e+01   5.86254e-02   6.61268e-04   4.65926e-03
#    2  p1           3.16593e+00   7.96234e-02   8.98112e-04   1.41296e-03
#    3  p2           2.55547e+03   5.51270e+01   6.34740e-01  -2.24871e-07
#  FCN=567.723 FROM MIGRAD    STATUS=CONVERGED     245 CALLS         246 TOTAL
#                      EDM=5.47356e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.0 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.06865e+01   5.75291e-02   7.66737e-04   8.41612e-03
#    2  p1           3.17086e+00   7.64546e-02   5.65330e-04  -3.31546e-03
#    3  p2           2.75900e+03   5.78460e+01   4.20257e-01   3.06429e-07
#    4  p3           1.77624e+01   6.14952e-01  -1.34780e-03   1.69825e-03
#    5  p4           2.30915e+03   6.00090e+01   3.26531e-01  -7.19191e-06
#  FCN=566.849 FROM MIGRAD    STATUS=CONVERGED     150 CALLS         151 TOTAL
#                      EDM=5.56444e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
# ...
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_mu_mass_PP (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: DY_allprobes (Potential memory leak).

# %%
cc = ROOT.TCanvas()
cc.Draw()
ee=[]
h_e = ROOT.TH1F("efficiency", "efficiency", 30, 0.8, 1)
for i in range(len(ea)):
    h_e.Fill(ea[i])
h_e.GetXaxis().SetTitle("efficicency")
h_e.GetYaxis().SetTitle("Counts/0.006 units")
h_e.Draw()
h_e.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: efficiency (Potential memory leak).

# %%
print("Max efficiency:",max(ea),"\nbackgroun efficiency:", params[3],"\n---------------------------------------\ndz at cut:",params[0],"\ndB at cut:",params[1],"\nisoDeposits at cut:",params[2])
# Out:
# Max efficiency: 0.9136520075854073
# backgroun efficiency: 0.05621046874092246
# ----------------------------------
# dz at cut: 0.014
# dB at cut: 0.007
# isoDeposits at cut: 9

# %% [markdown]
# ## Dataset Data.root
# Facciamo un efficiency scan e poi speriamo in gesù

# %%
ea = []
e_max = 0
#params[]
c2=ROOT.TCanvas()
h_epsilon = ROOT.TH1F("efficiency", "efficiency", 100, 0, 100)
for dzc in np.arange(0.007, 0.015 , 0.001):
    print("sono a dcz = ", dzc)
    for dBc in np.arange(0.006 , 0.010 , 0.001):
        for isoc in np.arange(4, 10, 1):

            h_pass = ROOT.TH1F("mu_mass_PP"," Muon mass PP",150,0,150)
            h_all = ROOT.TH1F("allprobes","All probes",150,0,150) 

            for i in range(tr.GetEntries()): #inizio ciclo che crea istogramma con la scelta di parametri
                tr.GetEntry(i)
                if(tr.muontracks_size>1):
                    muons = pt.get_collection(tr, "muontracks")
                    for mi in range(len(muons)):
                        if(tr.muontracks_chi2[mi]<1.8 and tr.muontracks_chi2[mi]>0.2 and tr.muontracks_dz[mi]<0.005 and tr.muontracks_dB[mi]<0.003 and tr.muontracks_isoDeposits[mi]<4):
                            p4t=muons[mi].p4
                            for mj in range(len(muons)):
                                if(mj != mi):
                                    p4ap = muons[mj].p4
                                    s_all = (p4t+p4ap).M()
                                    h_all.Fill(s_all)
                                    
                                    if(tr.muontracks_dz[mj]<dzc and tr.muontracks_dB[mj]<dBc and tr.muontracks_isoDeposits[mj]<isoc):
                                        p4pp = muons[mj].p4
                                        s_pass = (p4t+p4pp).M()
                                        h_pass.Fill(s_pass)
            
            pp = ROOT.TF1("gauss", "[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            ap = ROOT.TF1("exp+gauss", "[4]/[3]*TMath::Exp(-x/[3]) + [2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5, 140)
            pp.SetParameters(50,10,50)
            ap.SetParameters(90,10,10,500,100)
            h_all.Fit(ap, "SR")
            h_pass.Fit(pp,"SR")
            n_p=pp.Integral(5,140)

            bkg=ROOT.TF1("Background gauss","[1]/[0]*TMath::Exp(-x/[0])",5,140)
            bkg.SetParameters(ap.GetParameter(3),ap.GetParameter(4))
            n_b = bkg.Integral(5,140)
            
            sig=ROOT.TF1("Signal Gauss","[2]*1/([1]*TMath::Sqrt(2*TMath::Pi()))*exp(-((x-[0])*(x-[0]))/(TMath::Sqrt(2)*[1]*[1]))", 5,140)
            sig.SetParameters(ap.GetParameter(0),ap.GetParameter(1),ap.GetParameter(2))
            n_s=sig.Integral(5,140)

            ei,eb=pt.eff(n_s,n_b,n_p)
            ea.append(ei)
            if(ei>=max(ea)): 
                params=[dzc,dBc,isoc,eb]
print("Max efficiency:",max(ea),"\ndz at cut:",params[0],"\ndB at cut:",params[1],"\nisoDeposits at cut:",params[2])

# %%
print("Max efficiency:",max(ea),"\ndz at cut:",params[0],"\ndB at cut:",params[1],"\nisoDeposits at cut:",params[2], )

# %%
cc = ROOT.TCanvas()
cc.Draw()
ee=[]
h_e = ROOT.TH1F("efficiency", "efficiency", 50, 0.75, 1)
for i in range(len(ea)):
    h_e.Fill(ea[i])
h_e.Draw()
