# %% [markdown]
# # Step 2 - Test d'ipotesi
# Vogliamo testare l'ipotesi di solo fondo con quella di Segnale + Fondo ed entrambe saranno testate effettuando la correzione dell'aggiunta di 7.905 eventi, come osservato debba accadere nel notebook *04_cut_revert.ipynb*
#
# ---
# ---
# ### Primo approccio
# * La notra test statistic è il numero di eventi attesi
# * Chiamo le ipotesi di segnale+fondo e solo fondo rispettivamente Hs e Hb
#     * L'ipotesi di segnale + fondo corrisponde ad una poissoniana centrata a $\nu = 5.2 + 7.9 = 13.1$
#     * L'ipotesi di solo fondo corrisponde ad una poissoniana centrata a $\nu = 2.8+7.9 = 10.7$
# * Cerco un valore per il cut della test statistic tale da permettermi di avere una signal efficiency del 95%, ossia un significance level del 5%
#     + A questo sarà quindi legato un certo valore che è la probabilità di star sbagliando a scegliere tale ipotesi, ossia l'integrale della distribuzione di BG nella zona del taglio decisa come segnale
#
# ### Secondo approccio
# * La notra test statistic è il numero di eventi attesi
# * Chiamo le ipotesi di segnale+fondo e solo fondo rispettivamente Hs e Hb
#     * L'ipotesi di segnale + fondo corrisponde ad una poissoniana centrata a $\nu = 5.2 + 7.9 = 13.1$
#     * L'ipotesi di solo fondo corrisponde ad una poissoniana centrata a $\nu = 2.8+7.9 = 10.7$
# * Il cut viene effettuato esattamente dove si trovano i miei dati, così da poter dire che per $t\geq t_{cut}$ ho un certo significance level del mio segnale
#     + A questo sarà quindi legato un certo valore che è la probabilità di star sbagliando a scegliere tale ipotesi, ossia l'integrale della distribuzione di BG nella zona del taglio decisa come segnale
#
# ---
# ## Cosa succede se includiamo il cut dei muoni?
# * Ripeto i due approcci precedenti e ricalcolo una significance

# %%
import ROOT
import particle as pt
import funx as fx
import numpy as np
# Out:
# Welcome to JupyROOT 6.26/04

# %% [markdown]
# ## Cut standard
# ### Approccio 1

# %%
Hb1 = ROOT.TF1("Backgroun hypotesis" , "TMath::Poisson(x,10.7)",0, 30)  #Solo GB
Hs1 = ROOT.TF1("Signal hypotesis" , "TMath::Poisson(x,13.1)",0, 30)     #BG+Signal

c=ROOT.TCanvas()
c.Draw()
Hb1.SetLineColor(ROOT.kBlue)
Hb1.Draw()
Hs1.Draw("SAME")

leg = ROOT.TLegend(0.98,0.9,0.78,0.75) #x1,y1 (coordinate punto alto dx), x2,y2 (coordinate punto basso sx)
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(Hb1, "BKG","f")            
leg.AddEntry(Hs1, "BKG+SIG","f")
leg.Draw()

# %%
alpha = Hs1.Integral(0,7.5)  #Con 7.5 ottengo significance del 5%
#print("Significance: ", alpha)
efficiency = Hs1.Integral(7.5,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb1.Integral(0,7.5)
misID = Hb1.Integral(7.5,45)
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.0519964576829405
# Efficiency:  0.948003008139
#
# Misidentification Probability:  0.8353303542072189
# Rejection Power:  0.16466350395868407

# %% [markdown]
# ### Approccio 2

# %%
Hb = ROOT.TF1("Backgroun hypotesis" , "TMath::Poisson(x,10.7)",0, 30)  #Solo GB
Hs = ROOT.TF1("Signal hypotesis" , "TMath::Poisson(x,13.1)",0, 30)     #BG+Signal

c=ROOT.TCanvas()
c.Draw()
Hb.SetLineColor(ROOT.kBlue)
Hb.Draw()
Hs.Draw("SAME")

# %%
alpha = Hs.Integral(0,13)
efficiency = Hs.Integral(13,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb.Integral(0,13)  
misID = Hb.Integral(13,45)   #beta
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.5073820008683971
# Efficiency:  0.4926174649535439
#
# Misidentification Probability:  0.23364507846633573
# Rejection Power:  0.7663487796995672

# %% [markdown]
# ## Come esporre il discorso
# Il primo tentativo, di impostare a priori una significance che ci piacesse, ha dato un risultato sì decente del 95% di efficiency, ma rende molto alta la probabilità di misID a causa del fatto che ho dei conteggi e questi sono comunque troppo ravvicinati.
#
# Quindi come secondo test di ipotesi si è provato invece a decidere come cut della test statistic 13, ossia il valore effettivamente misurato nel dataset di interesse. Ciò ci ha permesso di ottenere sì una riduzione vistosa dell'efficiencì che praticamente arriva ad essere il 50%, abbassando la significance del nostro test, ma anche una riduzione molto forte della misID probability che arriva al 23%
#
# ---
# Qui sotto provo ora a fare un calcolo della significatività statistica, ossia che numero di deviazioni standard ci stiamo allontanando dall'ipotesi di solo fondo. Controllare gli appunti per la spiegazione, ma in teorai dovrebbe essere $$Z=\frac{S}{\sqrt{B}}$$

# %%
z=2.4/(np.sqrt(2.8))
print(z)
# Out:
# 1.4342743312012722

# %% [markdown]
# ---
# ## Cut alternativo comprensivo dei muoni
# A questo punto ripetiamo l'intero test utilizzando però questa volta il cut alternativo dei muoni avendo delle poissonaine centrate diversamente. Ricordiamo che qui il numero di eventi di segnale misurato non è  di 13, ma di 11.
# * Segnale + Fondo mi restituisce una poissoniana in $\nu = 2.3+0.9+7.9=11.1$
# * Solo fondo mi restituisce una poissoniana in $\nu = 0.9+7.9 = 8.8 $
# * I punti precedenti ci mostrano che qui le poissonaine sono molto più distinte e possiamoe effettivamente sperare in un risultato migliore
#
# ### Approccio 1

# %%
Hb1 = ROOT.TF1("Backgroun hypotesis" , "TMath::Poisson(x,8.8)",0, 30)  #Solo GB
Hs1 = ROOT.TF1("Signal hypotesis" , "TMath::Poisson(x,11.1)",0, 30)    #BG+Signal

c=ROOT.TCanvas()
c.Draw()
Hb1.SetLineColor(ROOT.kBlue)
Hb1.Draw()
Hs1.Draw("SAME")

leg = ROOT.TLegend(0.98,0.9,0.78,0.75) #x1,y1 (coordinate punto alto dx), x2,y2 (coordinate punto basso sx)
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(Hb1, "BKG","f")            
leg.AddEntry(Hs1, "BKG+SIG","f")
leg.Draw()

# %%
alpha = Hs1.Integral(0,5.99)  #Con 7.5 ottengo significance del 5%
#print("Significance: ", alpha)
efficiency = Hs1.Integral(6,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb1.Integral(0,6)
misID = Hb1.Integral(6,45)
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.05282085146938247
# Efficiency:  0.9467835231157081
#
# Misidentification Probability:  0.825460076089485
# Rejection Power:  0.17449712706422002

# %% [markdown]
# ### Approccio 2

# %%
Hb = ROOT.TF1("Backgroun hypotesis" , "TMath::Poisson(x,8.8)",0, 30)  #Solo GB
Hs = ROOT.TF1("Signal hypotesis" , "TMath::Poisson(x,11.1)",0, 30)     #BG+Signal

c=ROOT.TCanvas()
c.Draw()
Hb.SetLineColor(ROOT.kBlue)
Hb.Draw()
Hs.Draw("SAME")

# %%
alpha = Hs.Integral(0,11)
efficiency = Hs.Integral(11,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb.Integral(0,11)  
misID = Hb.Integral(11,45)   #beta
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.09467574302164253
# Efficiency:  0.9053242569783575
#
# Misidentification Probability:  0.4256343118441027
# Rejection Power:  0.5743656881445467

# %%
z=2.3/(np.sqrt(0.9))
print(z)
# Out:
# 2.4244128727957572

# %% [markdown]
# Qui il risultato della signifcance non è comunque entusiasmante, ma comunque è migliore del precedente, il ché è un indizio della superiorità di questo ultimo taglio

# %% [markdown]
# # Tentativi extra

# %% [markdown]
# Provo semplicemente cercare un taglio oltre il quale posso affermare di aver escluso il fondo al 95%

# %%
Hb1 = ROOT.TF1("Backgroun hypotesis" , "TMath::Poisson(x,10.7)",0, 30)  #Solo GB
Hs1 = ROOT.TF1("Signal hypotesis" , "TMath::Poisson(x,13.1)",0, 30)     #BG+Signal

c=ROOT.TCanvas()
c.Draw()
Hb1.SetLineColor(ROOT.kBlue)
Hb1.Draw()
Hs1.Draw("SAME")

leg = ROOT.TLegend(0.98,0.9,0.78,0.75) #x1,y1 (coordinate punto alto dx), x2,y2 (coordinate punto basso sx)
leg.SetHeader("Legenda", "C")                         
leg.AddEntry(Hb1, "BKG","f")            
leg.AddEntry(Hs1, "BKG+SIG","f")
leg.Draw()

# %%
alpha = Hs1.Integral(0,16.3)
efficiency = Hs1.Integral(16.3,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb1.Integral(0,16.3)  
misID = Hb1.Integral(16.3,90)   #beta
#print(misID)
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.8141682415295616
# Efficiency:  0.1858312242923793
#
# Misidentification Probability:  0.05147326264564842
# Rejection Power:  0.9485205955202571

# %% [markdown]
# ---
# E se queste non fossero poissoniane, ma delle gaussiane? Alla fine sarebbe giustificato che, ad esempio, il valore 7.9 non ha la larghezza poissoniana che è la radice, perché tecnicamente sonoo estrapolate da altre grandezze. Ad occhio sembra ragionevole, dunque provo questo approccio dove uso delle gaussiane con errori leggermente diversi
# * Ipotesi di Segnale+Fondo: $\mu = 13.1 , \sigma = 1.6$
# * Ipotesi di solo fondo: $\mu = 10.7, \sigma = 1.6$

# %%
cc = ROOT.TCanvas()
Hb = ROOT.TF1("Backgroun hypotesis" , "TMath::Gaus(x,10.7,1.6,kTRUE)",0, 30)  #Solo GB
Hs = ROOT.TF1("Signal hypotesis" , "TMath::Gaus(x,13.1, 1.6,kTRUE)",0, 30)    #BG+Signal

cc.Draw()
Hb.SetLineColor(ROOT.kBlue)
Hb.Draw()
Hs.Draw("SAME")

# %%
alpha = Hs.Integral(0,13)
efficiency = Hs.Integral(13,45)
print("Significance: ", alpha, "\nEfficiency: ",efficiency)

rej_pow = Hb.Integral(0,13)  
misID = Hb.Integral(13,45)   #beta
print("\nMisidentification Probability: ", misID, "\nRejection Power: ",rej_pow)
# Out:
# Significance:  0.47508233097075275
# Efficiency:  0.5249176690292472
#
# Misidentification Probability:  0.07528798641242333
# Rejection Power:  0.9247120135762259
